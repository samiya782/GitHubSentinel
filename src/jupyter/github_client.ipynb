# %% [markdown]
# # 获取 GitHub 项目进展
#
# 以下代码主要由 GPT-4 生成，演示 `GitHubClient` 模块的版本演进。
#
#
# ## 使用 GitHub REST API 获取项目信息
#
# GitHub REST API 为开发者提供了便捷获取 GitHub 项目的丰富 API。
#
# ![Github Docs](images/github_docs.png)
#
# 例如，获取项目 issues 列表，GitHub 提供了 `"List repository issues"` API。
#
#
# ## GitHub Token 配置
#
# 使用 `GitHubClient` 模块调用 GitHub REST API 需要配置 [GitHub Fine-grained personal access token](https://github.com/settings/tokens?type=beta)。
#
# - **配置文件**：正式启动 GitHubSentinel 项目，可以替换 `config.json` 中 `github_token` 值。
# - **Jupyter测试**：在使用构造函数实例化 GitHubClient 类，以参数形式传入。
#
# 下面以 https://github.com/langchain-ai/langchain 项目为例，演示 GitHubClient 使用方法

# %% [markdown]
# ## [v0.2] GitHubClient Class

# %%
# src/github_client.py

import requests  # 导入requests库用于发起HTTP请求
import datetime  # 导入datetime库处理日期和时间

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub的访问令牌
        # 初始化请求头部，这里主要是为了使用GitHub的API进行身份验证
        self.headers = {'Authorization': f'token {self.token}'}

    def fetch_updates(self, repos):
        # 为给定的仓库列表获取更新，包括提交、问题和拉取请求
        updates = {}
        for repo in repos:
            # 遍历每个仓库并获取相关信息
            updates[repo] = {
                'commits': self.fetch_commits(repo),  # 获取提交记录
                'issues': self.fetch_issues(repo),   # 获取问题
                'pull_requests': self.fetch_pull_requests(repo)  # 获取拉取请求
            }
        return updates

    def fetch_commits(self, repo):
        # 构建获取提交记录的API URL
        url = f'https://api.github.com/repos/{repo}/commits'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 检查请求是否成功，如果出错则抛出异常
        return response.json()  # 返回解析JSON格式的数据

    def fetch_issues(self, repo):
        # 构建获取问题(issue)的API URL
        url = f'https://api.github.com/repos/{repo}/issues'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 确保响应没有HTTP错误
        return response.json()  # 返回JSON数据

    def fetch_pull_requests(self, repo):
        # 构建获取拉取请求(pull requests)的API URL
        url = f'https://api.github.com/repos/{repo}/pulls'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()
        return response.json()  # 返回JSON格式的拉取请求数据

    def export_daily_progress(self, repo):
        # 导出指定仓库的每日进度，包括问题和拉取请求
        date_str = datetime.datetime.now().strftime('%Y-%m-%d')  # 获取当前日期字符串
        issues = self.fetch_issues(repo)  # 获取当天的问题
        pull_requests = self.fetch_pull_requests(repo)  # 获取当天的拉取请求
        filename = f"{repo.replace('/', '_')}_{date_str}.md"  # 根据仓库名和日期生成文件名

        # 打开文件进行写入
        with open(filename, 'w') as f:
            f.write(f"# {repo} Daily Progress - {date_str}\n\n")  # 写入标题
            f.write("## Issues\n")
            for issue in issues:
                f.write(f"- {issue['title']} #{issue['number']}\n")  # 列出每个问题
            f.write("\n## Pull Requests\n")
            for pr in pull_requests:
                f.write(f"- {pr['title']} #{pr['number']}\n")  # 列出每个拉取请求

        print(f"Exported daily progress to {filename}")  # 打印导出信息

        return filename

# %% [markdown]
# ### 实例化 GitHubClient
#
# 从环境变量中获取 `GITHUB_TOKEN`，依次获取 Commits, Issues 和 Pull Requests。

# %%
import os
from dotenv import load_dotenv
load_dotenv()
github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### List Issues API
#
# API完整文档说明见：https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues
#
# **请求样例**：`GET /repos/{owner}/{repo}/issues`;
#
# **返回样例**：
#
# ```json
# [
#   {
#     "id": 1,
#     "node_id": "MDU6SXNzdWUx",
#     "url": "https://api.github.com/repos/octocat/Hello-World/issues/1347",
#     "repository_url": "https://api.github.com/repos/octocat/Hello-World",
#     "labels_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/labels{/name}",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/comments",
#     "events_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/events",
#     "html_url": "https://github.com/octocat/Hello-World/issues/1347",
#     "number": 1347,
#     "state": "open",
#     "title": "Found a bug",
#     "body": "I'm having a problem with this.",
#     "user": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "labels": [
#       {
#         "id": 208045946,
#         "node_id": "MDU6TGFiZWwyMDgwNDU5NDY=",
#         "url": "https://api.github.com/repos/octocat/Hello-World/labels/bug",
#         "name": "bug",
#         "description": "Something isn't working",
#         "color": "f29513",
#         "default": true
#       }
#     ],
#     "assignee": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "assignees": [
#       {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       }
#     ],
#     "milestone": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/milestones/1",
#       "html_url": "https://github.com/octocat/Hello-World/milestones/v1.0",
#       "labels_url": "https://api.github.com/repos/octocat/Hello-World/milestones/1/labels",
#       "id": 1002604,
#       "node_id": "MDk6TWlsZXN0b25lMTAwMjYwNA==",
#       "number": 1,
#       "state": "open",
#       "title": "v1.0",
#       "description": "Tracking milestone for version 1.0",
#       "creator": {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       },
#       "open_issues": 4,
#       "closed_issues": 8,
#       "created_at": "2011-04-10T20:09:31Z",
#       "updated_at": "2014-03-03T18:58:10Z",
#       "closed_at": "2013-02-12T13:22:01Z",
#       "due_on": "2012-10-09T23:39:01Z"
#     },
#     "locked": true,
#     "active_lock_reason": "too heated",
#     "comments": 0,
#     "pull_request": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/pulls/1347",
#       "html_url": "https://github.com/octocat/Hello-World/pull/1347",
#       "diff_url": "https://github.com/octocat/Hello-World/pull/1347.diff",
#       "patch_url": "https://github.com/octocat/Hello-World/pull/1347.patch"
#     },
#     "closed_at": null,
#     "created_at": "2011-04-22T13:33:48Z",
#     "updated_at": "2011-04-22T13:33:48Z",
#     "closed_by": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "author_association": "COLLABORATOR",
#     "state_reason": "completed"
#   }
# ]
# ```

# %%
repo = "langchain-ai/langchain"

# %%
issues = github_client.fetch_issues(repo)

# %% [markdown]
# ### GitHubClient fetch 方法 repo 参数格式要求
#
# 从 GitHub 获取项目进展，需要访问形如 `https://api.github.com/repos/{repo}/issues`(以issues为例）的 URL。因此，repo 必须符合 GitHub Repo 标准命名，如下所示:
#
# ```json
# [
#     "langchain-ai/langchain",
#     "DjangoPeng/openai-quickstart",
#     "ollama/ollama"
# ]
# ```
#
# **GitHubSentinel 项目订阅管理配置文件为 `subscriptions.json`。**

# %%
issues
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31876',
#   'id': 3203320591,
#   'node_id': 'PR_kwDOIPDwls6debd-',
#   'number': 31876,
#   'title': 'langchain: Add ruff rule W',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T17:07:04Z',
#   'updated_at': '2025-07-04T17:21:35Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31876',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31876',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31876.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31876.patch',
#    'merged_at': None},
#   'body': 'All auto-fixes\r\nSee https://docs.astral.sh/ruff/rules/#warning-w',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31875',
#   'id': 3203304062,
#   'node_id': 'PR_kwDOIPDwls6deYBA',
#   'number': 31875,
#   'title': 'langchain: Add ruff rule RET',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T16:57:04Z',
#   'updated_at': '2025-07-04T17:05:41Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31875',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31875',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31875.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31875.patch',
#    'merged_at': None},
#   'body': 'All auto-fixes\r\nSee https://docs.astral.sh/ruff/rules/#flake8-return-ret',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31874',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31874/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31874/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31874/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31874',
#   'id': 3203264400,
#   'node_id': 'PR_kwDOIPDwls6dePq6',
#   'number': 31874,
#   'title': 'langchain: Add ruff rule RUF',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T16:34:05Z',
#   'updated_at': '2025-07-04T17:10:47Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31874',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31874',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31874.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31874.patch',
#    'merged_at': None},
#   'body': 'All auto-fixes\r\nSee https://docs.astral.sh/ruff/rules/#ruff-specific-rules-ruf',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31874/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31874/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31873',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31873/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31873/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31873/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31873',
#   'id': 3203249633,
#   'node_id': 'PR_kwDOIPDwls6deMbJ',
#   'number': 31873,
#   'title': 'langchain: Add ruff rules EM',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T16:28:10Z',
#   'updated_at': '2025-07-04T16:34:50Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31873',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31873',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31873.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31873.patch',
#    'merged_at': None},
#   'body': 'All auto-fixes.\r\nSee https://docs.astral.sh/ruff/rules/#flake8-errmsg-em',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31873/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31873/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31870',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31870/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31870/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31870/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/31870',
#   'id': 3203049955,
#   'node_id': 'I_kwDOIPDwls6-6qnj',
#   'number': 31870,
#   'title': 'String Evaluation with labelled criteria Scoring is wrong',
#   'user': {'login': 'vinodreddy-bs',
#    'id': 105217169,
#    'node_id': 'U_kgDOBkV8kQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105217169?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vinodreddy-bs',
#    'html_url': 'https://github.com/vinodreddy-bs',
#    'followers_url': 'https://api.github.com/users/vinodreddy-bs/followers',
#    'following_url': 'https://api.github.com/users/vinodreddy-bs/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vinodreddy-bs/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vinodreddy-bs/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vinodreddy-bs/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vinodreddy-bs/orgs',
#    'repos_url': 'https://api.github.com/users/vinodreddy-bs/repos',
#    'events_url': 'https://api.github.com/users/vinodreddy-bs/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vinodreddy-bs/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 6411661606,
#     'node_id': 'LA_kwDOIPDwls8AAAABfioxJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/investigate',
#     'name': 'investigate',
#     'color': '4D8397',
#     'default': False,
#     'description': 'Flagged for investigation.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-07-04T15:02:02Z',
#   'updated_at': '2025-07-04T15:02:28Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': '### Checked other resources\n\n- [x] I added a very descriptive title to this issue.\n- [x] I used the GitHub search to find a similar question and didn\'t find it.\n- [x] I am sure that this is a bug in LangChain rather than my code.\n- [x] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n- [x] I posted a self-contained, minimal, reproducible example. A maintainer can copy it and run it AS IS.\n\n### Example Code\n\n```python\nevaluator = load_evaluator(EvaluatorType.LABELED_CRITERIA, llm=llm, criteria=param_criteria)\n  eval_result = evaluator.evaluate_strings(\n      prediction=param_prediction,\n      input=param_input,\n      reference=param_reference\n  )\nreturn eval_result\n```\n\n### Error Message and Stack Trace (if applicable)\n\n### Reasoning\n\n\n`{\'reasoning\': \'Step-by-step reasoning:\\n\\n1. Understand the user objective:  \\n   The objective is to "Set the flight dates for any dates which has 5 days of difference in departure and return dates."  \\n   The expected steps are:  \\n   - Select a date in the departure date picker  \\n   - Select a date in the return date picker  \\n\\n2. Analyze the actual steps performed in the submission:  \\n   - "Close the login popup"  \\n   - "Click on the return date field to open the date picker."  \\n   - "Click on 10th July 2025 to select the return date."  \\n\\n3. Check if the submission fulfills the objective:  \\n   - The submission only interacts with the return date picker and selects a return date.  \\n   - There is no mention or action related to selecting a departure date.  \\n   - The objective requires setting both departure and return dates with a 5-day difference.  \\n   - The submission does not set the departure date at all, so it is incomplete.  \\n\\n4. Check correctness and factual accuracy:  \\n   - The steps performed are factually correct actions but incomplete relative to the objective.  \\n   - Closing the login popup is not part of the objective but may be a prerequisite; this is acceptable if it does not interfere.  \\n   - Selecting only the return date without selecting the departure date means the objective is not fully met.  \\n\\n5. Conclusion:  \\n   - The submission does not meet the criteria of correctness because it fails to perform all required actions (missing departure date selection).  \\n   - Therefore, the submission is incomplete and does not fulfill the objective as specified.\\n\\nY\', \'value\': \'Y\', \'score\': 1}`\n\n### Description\n\n- I am expecting a `N` here, but received `Y`\n- Reasoning clearly mentioned that it doesn\'t meet the requirements but still passed\n\n### System Info\n\nSystem Information\n------------------\n> OS:  Darwin\n> OS Version:  Darwin Kernel Version 24.0.0: Mon Aug 12 20:49:48 PDT 2024; root:xnu-11215.1.10~2/RELEASE_ARM64_T8103\n> Python Version:  3.9.6 (default, Aug  9 2024, 14:24:13) \n[Clang 16.0.0 (clang-1600.0.26.3)]\n\nPackage Information\n-------------------\n> langchain_core: 0.3.56\n> langchain: 0.3.24\n> langchain_community: 0.3.23\n> langsmith: 0.2.10\n> langchain_anthropic: 0.3.10\n> langchain_openai: 0.2.14\n> langchain_text_splitters: 0.3.8\n\nOptional packages not installed\n-------------------------------\n> langserve\n\nOther Dependencies\n------------------\n> aiohttp<4.0.0,>=3.8.3: Installed. No version info available.\n> anthropic<1,>=0.49.0: Installed. No version info available.\n> async-timeout<5.0.0,>=4.0.0;: Installed. No version info available.\n> dataclasses-json<0.7,>=0.5.7: Installed. No version info available.\n> httpx: 0.27.0\n> httpx-sse<1.0.0,>=0.4.0: Installed. No version info available.\n> jsonpatch<2.0,>=1.33: Installed. No version info available.\n> langchain-anthropic;: Installed. No version info available.\n> langchain-aws;: Installed. No version info available.\n> langchain-azure-ai;: Installed. No version info available.\n> langchain-cohere;: Installed. No version info availab ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31870/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31870/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31869',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31869/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31869/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31869/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31869',
#   'id': 3202719329,
#   'node_id': 'PR_kwDOIPDwls6dce9M',
#   'number': 31869,
#   'title': 'standard-tests: Add ruff rules PGH',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T13:15:03Z',
#   'updated_at': '2025-07-04T13:26:59Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31869',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31869',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31869.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31869.patch',
#    'merged_at': None},
#   'body': 'See https://docs.astral.sh/ruff/rules/#pygrep-hooks-pgh',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31869/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31869/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31868',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31868/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31868/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31868/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31868',
#   'id': 3202558961,
#   'node_id': 'PR_kwDOIPDwls6db7db',
#   'number': 31868,
#   'title': 'core: make ruff rule PLW1510 unfixable',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T12:25:27Z',
#   'updated_at': '2025-07-04T12:32:13Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31868',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31868',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31868.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31868.patch',
#    'merged_at': None},
#   'body': 'See https://github.com/astral-sh/ruff/discussions/17087#discussioncomment-12675815\r\n\r\nTha autofix is misleading: it chooses to add `check=False` to keep the runtime behavior but in reality it hides the fact that most probably the user would prefer `check=True`.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31868/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31868/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31867',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31867/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31867/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31867/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31867',
#   'id': 3202291460,
#   'node_id': 'PR_kwDOIPDwls6dbAlC',
#   'number': 31867,
#   'title': 'langchain: Bump ruff version to 0.12',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T11:07:16Z',
#   'updated_at': '2025-07-04T11:14:27Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31867',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31867',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31867.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31867.patch',
#    'merged_at': None},
#   'body': None,
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31867/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31867/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31866',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31866/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31866/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31866/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31866',
#   'id': 3202259322,
#   'node_id': 'PR_kwDOIPDwls6da5_T',
#   'number': 31866,
#   'title': 'text-splitters: Bump ruff version to 0.12',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T10:58:24Z',
#   'updated_at': '2025-07-04T11:05:19Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31866',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31866',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31866.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31866.patch',
#    'merged_at': None},
#   'body': None,
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31866/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31866/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31865',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31865/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31865/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31865/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31865',
#   'id': 3202242926,
#   'node_id': 'PR_kwDOIPDwls6da2Wv',
#   'number': 31865,
#   'title': 'standard-tests: Bump ruff version to 0.12',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T10:53:30Z',
#   'updated_at': '2025-07-04T11:00:14Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31865',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31865',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31865.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31865.patch',
#    'merged_at': None},
#   'body': None,
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31865/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31865/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31864',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31864/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31864/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31864/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31864',
#   'id': 3202232114,
#   'node_id': 'PR_kwDOIPDwls6daz8m',
#   'number': 31864,
#   'title': 'cli: Bump ruff version to 0.12',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T10:50:03Z',
#   'updated_at': '2025-07-04T10:56:40Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31864',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31864',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31864.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31864.patch',
#    'merged_at': None},
#   'body': None,
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31864/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31864/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31863',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31863/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31863/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31863/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31863',
#   'id': 3201846151,
#   'node_id': 'PR_kwDOIPDwls6dZfAo',
#   'number': 31863,
#   'title': 'cli: Ruff autofixes',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T08:46:16Z',
#   'updated_at': '2025-07-04T10:50:11Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31863',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31863',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31863.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31863.patch',
#    'merged_at': None},
#   'body': 'Auto-fixes from ruff with rule ALL',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31863/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31863/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31862',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31862/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31862/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31862/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31862',
#   'id': 3201762822,
#   'node_id': 'PR_kwDOIPDwls6dZNQE',
#   'number': 31862,
#   'title': 'standard-tests: Ruff autofixes',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-04T08:13:03Z',
#   'updated_at': '2025-07-04T10:36:46Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31862',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31862',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31862.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31862.patch',
#    'merged_at': None},
#   'body': 'Auto-fixes from ruff with rule ALL',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31862/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31862/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31860',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31860/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31860/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31860/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31860',
#   'id': 3200837570,
#   'node_id': 'PR_kwDOIPDwls6dWJ0F',
#   'number': 31860,
#   'title': 'fix(docs): migrate from PGVector to PGVectorStore',
#   'user': {'login': 'itz-Amethyst',
#    'id': 91905413,
#    'node_id': 'U_kgDOBXpdhQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91905413?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/itz-Amethyst',
#    'html_url': 'https://github.com/itz-Amethyst',
#    'followers_url': 'https://api.github.com/users/itz-Amethyst/followers',
#    'following_url': 'https://api.github.com/users/itz-Amethyst/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/itz-Amethyst/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/itz-Amethyst/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/itz-Amethyst/subscriptions',
#    'organizations_url': 'https://api.github.com/users/itz-Amethyst/orgs',
#    'repos_url': 'https://api.github.com/users/itz-Amethyst/repos',
#    'events_url': 'https://api.github.com/users/itz-Amethyst/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/itz-Amethyst/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-03T22:51:39Z',
#   'updated_at': '2025-07-03T23:03:25Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31860',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31860',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31860.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31860.patch',
#    'merged_at': None},
#   'body': 'Description:\r\n\r\nThis Pull Request address a migration-related issue mentioned in this issue #31824 using the deprecated `PGVector` class. The example in the Jupyter notebook has been updated to use `PGVectorStore`, which is the recommended replacement after the deprecation of `PGVector`.\r\n\r\nChanges Made:\r\n\r\n-  Updated the vector store tables to be compatible with the synchronous version of the `PGVectorStore` engine.\r\n\r\n-  Replaced integer IDs with `UUIDs` for document identifiers to prevent conflicts with the table’s default ID schema.\r\n\r\n-  Revised examples in the notebook file to match with the migrated version.\r\n\r\nThis PR resolves the issue described in #31824, ',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31860/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31860/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31859',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31859/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31859/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31859/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31859',
#   'id': 3200815985,
#   'node_id': 'PR_kwDOIPDwls6dWFMH',
#   'number': 31859,
#   'title': 'harden xml parser for xmloutput agent',
#   'user': {'login': 'eyurtsev',
#    'id': 3205522,
#    'node_id': 'MDQ6VXNlcjMyMDU1MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3205522?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eyurtsev',
#    'html_url': 'https://github.com/eyurtsev',
#    'followers_url': 'https://api.github.com/users/eyurtsev/followers',
#    'following_url': 'https://api.github.com/users/eyurtsev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eyurtsev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eyurtsev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eyurtsev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eyurtsev/orgs',
#    'repos_url': 'https://api.github.com/users/eyurtsev/repos',
#    'events_url': 'https://api.github.com/users/eyurtsev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eyurtsev/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-07-03T22:34:43Z',
#   'updated_at': '2025-07-03T22:45:16Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31859',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/31859',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/31859.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/31859.patch',
#    'merged_at': None},
#   'body': 'Harden the default implementation of the XML parser for the agent',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31859/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31859/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31858',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31858/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31858/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31858/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31858',
#   'id': 3200736825,
#   'node_id': 'PR_kwDOIPDwls6dVzk4',
#   'number': 31858,
#   'title': 'text-splitters: Ruff autofixes',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
# ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31806/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31806/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31804',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31804/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31804/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31804/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/31804',
#   'id': 3192822496,
#   'node_id': 'I_kwDOIPDwls6-Tprg',
#   'number': 31804,
#   'title': '`load()` does not apply `secrets_map` to plain string values',
#   'user': {'login': 'Alioth99',
#    'id': 199570263,
#    'node_id': 'U_kgDOC-UzVw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/199570263?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Alioth99',
#    'html_url': 'https://github.com/Alioth99',
#    'followers_url': 'https://api.github.com/users/Alioth99/followers',
#    'following_url': 'https://api.github.com/users/Alioth99/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Alioth99/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Alioth99/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Alioth99/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Alioth99/orgs',
#    'repos_url': 'https://api.github.com/users/Alioth99/repos',
#    'events_url': 'https://api.github.com/users/Alioth99/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Alioth99/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-07-01T14:54:05Z',
#   'updated_at': '2025-07-01T14:56:31Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': '### Checked other resources\n\n- [x] I added a very descriptive title to this issue.\n- [x] I used the GitHub search to find a similar question and didn\'t find it.\n- [x] I am sure that this is a bug in LangChain rather than my code.\n- [x] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n- [x] I posted a self-contained, minimal, reproducible example. A maintainer can copy it and run it AS IS.\n\n### Example Code\n\n```python\nfrom langchain_core.load.load import load\n\n# Complex nested structure with secrets_map\nobj = {"key": "value", "secret": "__secret_key__"}\nsecrets_map = {"__secret_key__": "actual_secret"}\nresult = load(obj, secrets_map=secrets_map)\n\nprint(result["secret"])  # Should output: actual_secret\n```\n\n### Error Message and Stack Trace (if applicable)\n\n```\n__secret_key__\n```\n\n### Description\n\nWhen using `load(obj, secrets_map=...)`, secret placeholders in plain dicts are not replaced, even if they match a key in `secrets_map`.\n\n\n### System Info\n\nSystem Information\n------------------\n> OS:  Linux\n> OS Version:  #148-Ubuntu SMP Fri Mar 14 19:05:48 UTC 2025\n> Python Version:  3.10.16 (main, Dec 11 2024, 16:24:50) [GCC 11.2.0]\n\nPackage Information\n-------------------\n> langchain_core: 0.3.65\n> langchain: 0.3.25\n> langchain_community: 0.3.25\n> langsmith: 0.3.45\n> langchain_anthropic: 0.3.1\n> langchain_aws: 0.2.2\n> langchain_chroma: 0.2.0\n> langchain_cohere: 0.3.5\n> langchain_experimental: 0.3.2\n> langchain_fireworks: 0.2.6\n> langchain_google_vertexai: 2.0.5\n> langchain_groq: 0.2.2\n> langchain_mistralai: 0.2.4\n> langchain_openai: 0.2.14\n> langchain_text_splitters: 0.3.8\n> langchain_together: 0.2.0\n> langchain_unstructured: 0.1.5\n> langgraph_sdk: 0.1.34\n\nOptional packages not installed\n-------------------------------\n> langserve\n\nOther Dependencies\n------------------\n> aiohttp: 3.12.12\n> aiohttp<4.0.0,>=3.8.3: Installed. No version info available.\n> anthropic: 0.40.0\n> anthropic[vertexai]: Installed. No version info available.\n> async-timeout<5.0.0,>=4.0.0;: Installed. No version info available.\n> boto3: 1.35.42\n> chromadb: 0.5.23\n> cohere: 5.15.0\n> dataclasses-json<0.7,>=0.5.7: Installed. No version info available.\n> defusedxml: 0.7.1\n> fastapi: 0.115.9\n> fireworks-ai: 0.15.7\n> google-cloud-aiplatform: 1.70.0\n> google-cloud-storage: 2.18.2\n> groq: 0.11.0\n> httpx: 0.28.1\n> httpx-sse: 0.4.0\n> httpx-sse<1.0.0,>=0.4.0: Installed. No version info available.\n> jsonpatch<2.0,>=1.33: Installed. No version info available.\n> langchain-anthropic;: Installed. No version info available.\n> langchain-aws;: Installed. No version info available.\n> langchain-azure-ai;: Installed. No version info available.\n> langchain-cohere;: Installed. No version info available.\n> langchain-community;: Installed. No version info available.\n> langchain-core<1.0.0,>=0.3.51: Installed. No version info available.\n> langchain-core<1.0.0,>=0.3.58: Installed. No version info available.\n> langchain-core<1.0.0,>=0.3.65: Installed. No version info available.\n> langchain-deepseek;: Installed. No version info available.\n> langchain-fireworks;: Installed. No version info available.\n> langchain-google-genai;: Installed. No version info available.\n> langchain-google-vertexai;: Installed. No version info available.\n> langchain-groq;: Installed. No version info available.\n> langchain-huggingface;: Installed. No version info available.\n> langchain-mistralai;: Installed. No version info available.\n> langchain-ollama;: Installed. No version info available.\n> langchain-openai;: Installed. No version info available.\n> langchain-perplexity;: Installed. No version info available.\n> langchain-text-splitters<1.0.0,>=0.3.8: Installed. No version info available.\n> langchain-together;: Installed. No version info available.\n> langchain-xai;: Installed. No version info available.\n> langchain<1.0.0,>=0.3.25: I ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31804/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31804/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31802',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31802/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31802/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31802/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/31802',
#   'id': 3192752127,
#   'node_id': 'I_kwDOIPDwls6-TYf_',
#   'number': 31802,
#   'title': '`EvaluationResult.feedback_config` silently drops unknown or partial dict fields without error',
#   'user': {'login': 'Alioth99',
#    'id': 199570263,
#    'node_id': 'U_kgDOC-UzVw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/199570263?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Alioth99',
#    'html_url': 'https://github.com/Alioth99',
#    'followers_url': 'https://api.github.com/users/Alioth99/followers',
#    'following_url': 'https://api.github.com/users/Alioth99/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Alioth99/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Alioth99/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Alioth99/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Alioth99/orgs',
#    'repos_url': 'https://api.github.com/users/Alioth99/repos',
#    'events_url': 'https://api.github.com/users/Alioth99/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Alioth99/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2025-07-01T14:34:14Z',
#   'updated_at': '2025-07-03T13:14:38Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': '### Checked other resources\n\n- [x] I added a very descriptive title to this issue.\n- [x] I used the GitHub search to find a similar question and didn\'t find it.\n- [x] I am sure that this is a bug in LangChain rather than my code.\n- [x] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n- [x] I posted a self-contained, minimal, reproducible example. A maintainer can copy it and run it AS IS.\n\n### Example Code\n\n```python\nfrom langchain_core.tracers.evaluation import EvaluationResult\n\nresult = EvaluationResult(\n    key="sentiment",\n    value="positive",\n    feedback_config={"threshold": 1.0}\n)\nprint(result.feedback_config)  \n```\n\n### Error Message and Stack Trace (if applicable)\n\n{}\n\n### Description\n\nWhen passing a dict to `EvaluationResult.feedback_config`,  the data is silently discarded.\nThis causes unexpected behavior and makes it impossible to store arbitrary dict configurations directly, despite the type hint allowing `dict`.\n\n### System Info\n\nSystem Information\n------------------\n> OS:  Linux\n> OS Version:  #148-Ubuntu SMP Fri Mar 14 19:05:48 UTC 2025\n> Python Version:  3.10.16 (main, Dec 11 2024, 16:24:50) [GCC 11.2.0]\n\nPackage Information\n-------------------\n> langchain_core: 0.3.65\n> langchain: 0.3.25\n> langchain_community: 0.3.25\n> langsmith: 0.3.45\n> langchain_anthropic: 0.3.1\n> langchain_aws: 0.2.2\n> langchain_chroma: 0.2.0\n> langchain_cohere: 0.3.5\n> langchain_experimental: 0.3.2\n> langchain_fireworks: 0.2.6\n> langchain_google_vertexai: 2.0.5\n> langchain_groq: 0.2.2\n> langchain_mistralai: 0.2.4\n> langchain_openai: 0.2.14\n> langchain_text_splitters: 0.3.8\n> langchain_together: 0.2.0\n> langchain_unstructured: 0.1.5\n> langgraph_sdk: 0.1.34\n\nOptional packages not installed\n-------------------------------\n> langserve\n\nOther Dependencies\n------------------\n> aiohttp: 3.12.12\n> aiohttp<4.0.0,>=3.8.3: Installed. No version info available.\n> anthropic: 0.40.0\n> anthropic[vertexai]: Installed. No version info available.\n> async-timeout<5.0.0,>=4.0.0;: Installed. No version info available.\n> boto3: 1.35.42\n> chromadb: 0.5.23\n> cohere: 5.15.0\n> dataclasses-json<0.7,>=0.5.7: Installed. No version info available.\n> defusedxml: 0.7.1\n> fastapi: 0.115.9\n> fireworks-ai: 0.15.7\n> google-cloud-aiplatform: 1.70.0\n> google-cloud-storage: 2.18.2\n> groq: 0.11.0\n> httpx: 0.28.1\n> httpx-sse: 0.4.0\n> httpx-sse<1.0.0,>=0.4.0: Installed. No version info available.\n> jsonpatch<2.0,>=1.33: Installed. No version info available.\n> langchain-anthropic;: Installed. No version info available.\n> langchain-aws;: Installed. No version info available.\n> langchain-azure-ai;: Installed. No version info available.\n> langchain-cohere;: Installed. No version info available.\n> langchain-community;: Installed. No version info available.\n> langchain-core<1.0.0,>=0.3.51: Installed. No version info available.\n> langchain-core<1.0.0,>=0.3.58: Installed. No version info available.\n> langchain-core<1.0.0,>=0.3.65: Installed. No version info available.\n> langchain-deepseek;: Installed. No version info available.\n> langchain-fireworks;: Installed. No version info available.\n> langchain-google-genai;: Installed. No version info available.\n> langchain-google-vertexai;: Installed. No version info available.\n> langchain-groq;: Installed. No version info available.\n> langchain-huggingface;: Installed. No version info available.\n> langchain-mistralai;: Installed. No version info available.\n> langchain-ollama;: Installed. No version info available.\n> langchain-openai;: Installed. No version info available.\n> langchain-perplexity;: Installed. No version info available.\n> langchain-text-splitters<1.0.0,>=0.3.8: Installed. No version info available.\n> langchain-together;: Installed. No version info available.\n> langchain-xai;: Installed. No version info available.\n> langchain<1.0.0,>=0.3.25: Install ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31802/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31802/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# ### List Pull Requests API
#
# API完整文档说明见：https://docs.github.com/en/rest/pulls/pulls?apiVersion=2022-11-28#list-pull-requests
#
# **请求样例**：`GET /repos/{owner}/{repo}/pulls`;

# %%
pull_requests = github_client.fetch_pull_requests(repo)

# %%
pull_requests
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31876',
#   'id': 2641999742,
#   'node_id': 'PR_kwDOIPDwls6debd-',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31876',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/31876.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/31876.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876',
#   'number': 31876,
#   'state': 'open',
#   'locked': False,
#   'title': 'langchain: Add ruff rule W',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'body': 'All auto-fixes\r\nSee https://docs.astral.sh/ruff/rules/#warning-w',
#   'created_at': '2025-07-04T17:07:04Z',
#   'updated_at': '2025-07-04T17:21:35Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '7b161da9be59da42ff5677812c7a29e750e4510f',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31876/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31876/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/413c17d0e6ee46c055c2b6806df011a9b63cbd9e',
#   'head': {'label': 'cbornet:ruff-langchain-w',
#    'ref': 'ruff-langchain-w',
#    'sha': '413c17d0e6ee46c055c2b6806df011a9b63cbd9e',
#    'user': {'login': 'cbornet',
#     'id': 11633333,
#     'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/cbornet',
#     'html_url': 'https://github.com/cbornet',
#     'followers_url': 'https://api.github.com/users/cbornet/followers',
#     'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#     'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#     'repos_url': 'https://api.github.com/users/cbornet/repos',
#     'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'repo': {'id': 679193304,
#     'node_id': 'R_kgDOKHuq2A',
#     'name': 'langchain',
#     'full_name': 'cbornet/langchain',
#     'private': False,
#     'owner': {'login': 'cbornet',
#      'id': 11633333,
#      'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cbornet',
#      'html_url': 'https://github.com/cbornet',
#      'followers_url': 'https://api.github.com/users/cbornet/followers',
#      'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#      'repos_url': 'https://api.github.com/users/cbornet/repos',
#      'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/cbornet/langchain',
#     'description': '⚡ Building applications with LLMs through composability ⚡',
#     'fork': True,
#     'url': 'https://api.github.com/repos/cbornet/langchain',
#     'forks_url': 'https://api.github.com/repos/cbornet/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/cbornet/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/cbornet/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/cbornet/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/cbornet/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/cbornet/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/cbornet/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/cbornet/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/cbornet/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/cbornet/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/cbornet/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/cbornet/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/cbornet/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/cbornet/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/cbornet/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/cbornet/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/cbornet/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/cbornet/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/cbornet/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/cbornet/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/cbornet/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/cbornet/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/cbornet/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/cbornet/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/cbornet/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/cbornet/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/cbornet/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/cbornet/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/cbornet/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/cbornet/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/cbornet/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/cbornet/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/cbornet/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/cbornet/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/cbornet/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/cbornet/langchain/deployments',
#     'created_at': '2023-08-16T09:51:45Z',
#     'updated_at': '2025-07-04T10:58:26Z',
#     'pushed_at': '2025-07-04T17:14:28Z',
#     'git_url': 'git://github.com/cbornet/langchain.git',
#     'ssh_url': 'git@github.com:cbornet/langchain.git',
#     'clone_url': 'https://github.com/cbornet/langchain.git',
#     'svn_url': 'https://github.com/cbornet/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 380810,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 2,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 2,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2025-07-05T01:02:36Z',
#     'pushed_at': '2025-07-04T18:44:16Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 442950,
#     'stargazers_count': 110744,
#     'watchers_count': 110744,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 18022,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 298,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 18022,
#     'open_issues': 298,
#     'watchers': 110744,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31876'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/31876'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/31876/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31876/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31876/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/413c17d0e6ee46c055c2b6806df011a9b63cbd9e'}},
#   'author_association': 'COLLABORATOR',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31875',
#   'id': 2641985600,
#   'node_id': 'PR_kwDOIPDwls6deYBA',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31875',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/31875.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/31875.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875',
#   'number': 31875,
#   'state': 'open',
#   'locked': False,
#   'title': 'langchain: Add ruff rule RET',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'body': 'All auto-fixes\r\nSee https://docs.astral.sh/ruff/rules/#flake8-return-ret',
#   'created_at': '2025-07-04T16:57:04Z',
#   'updated_at': '2025-07-04T17:05:41Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': 'a2c8c6eba07304adddfea6a06586dddc38e30ee3',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31875/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31875/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/b32a4237c8b43d0a2ed70431b5659198e57a447d',
#   'head': {'label': 'cbornet:ruff-langchain-ret',
#    'ref': 'ruff-langchain-ret',
#    'sha': 'b32a4237c8b43d0a2ed70431b5659198e57a447d',
#    'user': {'login': 'cbornet',
#     'id': 11633333,
#     'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/cbornet',
#     'html_url': 'https://github.com/cbornet',
#     'followers_url': 'https://api.github.com/users/cbornet/followers',
#     'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#     'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#     'repos_url': 'https://api.github.com/users/cbornet/repos',
#     'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'repo': {'id': 679193304,
#     'node_id': 'R_kgDOKHuq2A',
#     'name': 'langchain',
#     'full_name': 'cbornet/langchain',
#     'private': False,
#     'owner': {'login': 'cbornet',
#      'id': 11633333,
#      'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cbornet',
#      'html_url': 'https://github.com/cbornet',
#      'followers_url': 'https://api.github.com/users/cbornet/followers',
#      'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#      'repos_url': 'https://api.github.com/users/cbornet/repos',
#      'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/cbornet/langchain',
#     'description': '⚡ Building applications with LLMs through composability ⚡',
#     'fork': True,
#     'url': 'https://api.github.com/repos/cbornet/langchain',
#     'forks_url': 'https://api.github.com/repos/cbornet/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/cbornet/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/cbornet/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/cbornet/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/cbornet/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/cbornet/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/cbornet/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/cbornet/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/cbornet/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/cbornet/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/cbornet/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/cbornet/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/cbornet/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/cbornet/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/cbornet/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/cbornet/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/cbornet/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/cbornet/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/cbornet/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/cbornet/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/cbornet/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/cbornet/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/cbornet/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/cbornet/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/cbornet/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/cbornet/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/cbornet/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/cbornet/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/cbornet/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/cbornet/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/cbornet/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/cbornet/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/cbornet/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/cbornet/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/cbornet/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/cbornet/langchain/deployments',
#     'created_at': '2023-08-16T09:51:45Z',
#     'updated_at': '2025-07-04T10:58:26Z',
#     'pushed_at': '2025-07-04T17:14:28Z',
#     'git_url': 'git://github.com/cbornet/langchain.git',
#     'ssh_url': 'git@github.com:cbornet/langchain.git',
#     'clone_url': 'https://github.com/cbornet/langchain.git',
#     'svn_url': 'https://github.com/cbornet/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 380810,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 2,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 2,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2025-07-05T01:02:36Z',
#     'pushed_at': '2025-07-04T18:44:16Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 442950,
#     'stargazers_count': 110744,
#     'watchers_count': 110744,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 18022,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 298,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 18022,
#     'open_issues': 298,
#     'watchers': 110744,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31875'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/31875'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/31875/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31875/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31875/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/b32a4237c8b43d0a2ed70431b5659198e57a447d'}},
#   'author_association': 'COLLABORATOR',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31874',
#   'id': 2641951418,
#   'node_id': 'PR_kwDOIPDwls6dePq6',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/31874',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/31874.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/31874.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31874',
#   'number': 31874,
#   'state': 'open',
#   'locked': False,
#   'title': 'langchain: Add ruff rule RUF',
#   'user': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'body': 'All auto-fixes\r\nSee https://docs.astral.sh/ruff/rules/#ruff-specific-rules-ruf',
#   'created_at': '2025-07-04T16:34:05Z',
#   'updated_at': '2025-07-04T17:10:47Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': 'a7704b9af198b0fdc7dc4eb425a40ee87600caf7',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31874/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31874/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31874/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/0c048a0a5a034149399ca2faf77503e23174b191',
#   'head': {'label': 'cbornet:ruff-langchain-ruf',
#    'ref': 'ruff-langchain-ruf',
#    'sha': '0c048a0a5a034149399ca2faf77503e23174b191',
#    'user': {'login': 'cbornet',
#     'id': 11633333,
#     'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/cbornet',
#     'html_url': 'https://github.com/cbornet',
#     'followers_url': 'https://api.github.com/users/cbornet/followers',
#     'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#     'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#     'repos_url': 'https://api.github.com/users/cbornet/repos',
#     'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'repo': {'id': 679193304,
#     'node_id': 'R_kgDOKHuq2A',
#     'name': 'langchain',
#     'full_name': 'cbornet/langchain',
#     'private': False,
#     'owner': {'login': 'cbornet',
#      'id': 11633333,
#      'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cbornet',
#      'html_url': 'https://github.com/cbornet',
#      'followers_url': 'https://api.github.com/users/cbornet/followers',
#      'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#      'repos_url': 'https://api.github.com/users/cbornet/repos',
#      'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/cbornet/langchain',
#     'description': '⚡ Building applications with LLMs through composability ⚡',
#     'fork': True,
#     'url': 'https://api.github.com/repos/cbornet/langchain',
#     'forks_url': 'https://api.github.com/repos/cbornet/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/cbornet/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/cbornet/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/cbornet/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/cbornet/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/cbornet/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/cbornet/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/cbornet/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/cbornet/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/cbornet/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/cbornet/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/cbornet/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/cbornet/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/cbornet/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/cbornet/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/cbornet/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/cbornet/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/cbornet/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/cbornet/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/cbornet/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/cbornet/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/cbornet/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/cbornet/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/cbornet/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/cbornet/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/cbornet/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/cbornet/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/cbornet/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/cbornet/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/cbornet/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/cbornet/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/cbornet/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/cbornet/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/cbornet/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/cbornet/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/cbornet/langchain/deployments',
#     'created_at': '2023-08-16T09:51:45Z',
#     'updated_at': '2025-07-04T10:58:26Z',
#     'pushed_at': '2025-07-04T17:14:28Z',
#     'git_url': 'git://github.com/cbornet/langchain.git',
#     'ssh_url': 'git@github.com:cbornet/langchain.git',
#     'clone_url': 'https://github.com/cbornet/langchain.git',
#     'svn_url': 'https://github.com/cbornet/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 380810,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 2,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 2,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
# ...
#     'name': 'size:M',
#     'color': 'FEF2C0',
#     'default': False,
#     'description': 'This PR changes 30-99 lines, ignoring generated files.'},
#    {'id': 7110712909,
#     'node_id': 'LA_kwDOIPDwls8AAAABp9TeTQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/langchain',
#     'name': 'langchain',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Related to the langchain package'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31730/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31730/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/31730/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/4a1994abb06cac547c56d7d9d6b35d945a19b866',
#   'head': {'label': 'ch-amal0:usage_metadata_perplexity',
#    'ref': 'usage_metadata_perplexity',
#    'sha': '4a1994abb06cac547c56d7d9d6b35d945a19b866',
#    'user': {'login': 'ch-amal0',
#     'id': 98335250,
#     'node_id': 'U_kgDOBdx6Eg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/98335250?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ch-amal0',
#     'html_url': 'https://github.com/ch-amal0',
#     'followers_url': 'https://api.github.com/users/ch-amal0/followers',
#     'following_url': 'https://api.github.com/users/ch-amal0/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ch-amal0/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ch-amal0/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ch-amal0/subscriptions',
#     'organizations_url': 'https://api.github.com/users/ch-amal0/orgs',
#     'repos_url': 'https://api.github.com/users/ch-amal0/repos',
#     'events_url': 'https://api.github.com/users/ch-amal0/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/ch-amal0/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'repo': {'id': 1008464651,
#     'node_id': 'R_kgDOPBvzCw',
#     'name': 'langchain',
#     'full_name': 'ch-amal0/langchain',
#     'private': False,
#     'owner': {'login': 'ch-amal0',
#      'id': 98335250,
#      'node_id': 'U_kgDOBdx6Eg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/98335250?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ch-amal0',
#      'html_url': 'https://github.com/ch-amal0',
#      'followers_url': 'https://api.github.com/users/ch-amal0/followers',
#      'following_url': 'https://api.github.com/users/ch-amal0/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ch-amal0/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ch-amal0/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ch-amal0/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ch-amal0/orgs',
#      'repos_url': 'https://api.github.com/users/ch-amal0/repos',
#      'events_url': 'https://api.github.com/users/ch-amal0/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ch-amal0/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/ch-amal0/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/ch-amal0/langchain',
#     'forks_url': 'https://api.github.com/repos/ch-amal0/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/ch-amal0/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/ch-amal0/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/ch-amal0/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/ch-amal0/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/ch-amal0/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/ch-amal0/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/ch-amal0/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/ch-amal0/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/ch-amal0/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/ch-amal0/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/ch-amal0/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/ch-amal0/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/ch-amal0/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/ch-amal0/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/ch-amal0/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/ch-amal0/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/ch-amal0/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/ch-amal0/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/ch-amal0/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/ch-amal0/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/ch-amal0/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/ch-amal0/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/ch-amal0/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/ch-amal0/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/ch-amal0/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/ch-amal0/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/ch-amal0/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/ch-amal0/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/ch-amal0/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/ch-amal0/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/ch-amal0/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/ch-amal0/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/ch-amal0/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/ch-amal0/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/ch-amal0/langchain/deployments',
#     'created_at': '2025-06-25T15:27:31Z',
#     'updated_at': '2025-06-25T15:27:31Z',
#     'pushed_at': '2025-06-27T15:44:00Z',
#     'git_url': 'git://github.com/ch-amal0/langchain.git',
#     'ssh_url': 'git@github.com:ch-amal0/langchain.git',
#     'clone_url': 'https://github.com/ch-amal0/langchain.git',
#     'svn_url': 'https://github.com/ch-amal0/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 375829,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '3c3320ae30151b20b4f59df7079b061329712080',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2025-07-05T01:02:36Z',
#     'pushed_at': '2025-07-04T18:44:16Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 442950,
#     'stargazers_count': 110744,
#     'watchers_count': 110744,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 18022,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 298,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 18022,
#     'open_issues': 298,
#     'watchers': 110744,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31730'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/31730'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/31730'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/31730/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31730/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/31730/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/4a1994abb06cac547c56d7d9d6b35d945a19b866'}},
#   'author_association': 'NONE',
#   'auto_merge': None,
#   'active_lock_reason': None}]

# %% [markdown]
# ### List Commits API
#
# API完整文档说明见：https://docs.github.com/en/rest/commits/commits?apiVersion=2022-11-28
#
# **请求样例**：`GET /repos/{owner}/{repo}/commits`;

# %%
commits = github_client.fetch_commits(repo)

# %%
commits
# Out:
# [{'sha': 'b26d2250ba88708a75d65d2542783adeaa2bb0ef',
#   'node_id': 'C_kwDOIPDwltoAKGIyNmQyMjUwYmE4ODcwOGE3NWQ2NWQyNTQyNzgzYWRlYWEyYmIwZWY',
#   'commit': {'author': {'name': 'Mohammad Mohtashim',
#     'email': '45242107+keenborder786@users.noreply.github.com',
#     'date': '2025-07-04T18:44:16Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-04T18:44:16Z'},
#    'message': 'core[patch]: Int Combine when Merging Dicts (#31572)\n\n- **Description:** Combining the Int Types by adding them which makes\nthe most sense.\n- **Issue:**  #31565',
#    'tree': {'sha': 'c59e6e86f1655909a36a8f043557a4d5b83b21e6',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/c59e6e86f1655909a36a8f043557a4d5b83b21e6'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/b26d2250ba88708a75d65d2542783adeaa2bb0ef',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nP1W0wn37VCt+0THkcT1H\n=ld3c\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree c59e6e86f1655909a36a8f043557a4d5b83b21e6\nparent 6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3\nauthor Mohammad Mohtashim <45242107+keenborder786@users.noreply.github.com> 1751654656 +0500\ncommitter GitHub <noreply@github.com> 1751654656 -0400\n\ncore[patch]: Int Combine when Merging Dicts (#31572)\n\n- **Description:** Combining the Int Types by adding them which makes\nthe most sense.\n- **Issue:**  #31565',
#     'verified_at': '2025-07-04T18:44:16Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b26d2250ba88708a75d65d2542783adeaa2bb0ef',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/b26d2250ba88708a75d65d2542783adeaa2bb0ef',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b26d2250ba88708a75d65d2542783adeaa2bb0ef/comments',
#   'author': {'login': 'keenborder786',
#    'id': 45242107,
#    'node_id': 'MDQ6VXNlcjQ1MjQyMTA3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45242107?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/keenborder786',
#    'html_url': 'https://github.com/keenborder786',
#    'followers_url': 'https://api.github.com/users/keenborder786/followers',
#    'following_url': 'https://api.github.com/users/keenborder786/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/keenborder786/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/keenborder786/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/keenborder786/subscriptions',
#    'organizations_url': 'https://api.github.com/users/keenborder786/orgs',
#    'repos_url': 'https://api.github.com/users/keenborder786/repos',
#    'events_url': 'https://api.github.com/users/keenborder786/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/keenborder786/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3'}]},
#  {'sha': '6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3',
#   'node_id': 'C_kwDOIPDwltoAKDZhNTA3M2IyMjdmZWZmNjdlYWU3ZWJmNTFjZGMzYmRjOGQwOWM0YjM',
#   'commit': {'author': {'name': 'Mason Daugherty',
#     'email': 'mason@langchain.dev',
#     'date': '2025-07-03T18:20:33Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-03T18:20:33Z'},
#    'message': 'langchain[patch]: Add bandit rules (#31818)\n\nIntegrate Bandit for security analysis, suppress warnings for specific issues, and address potential vulnerabilities such as hardcoded passwords and SQL injection risks. Adjust documentation and formatting for clarity.',
#    'tree': {'sha': '8a13ca141835860e146f407c2a639f89c89f5a09',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/8a13ca141835860e146f407c2a639f89c89f5a09'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nbYxM1EFdiFvk7cj0qfiv\n=eIsa\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 8a13ca141835860e146f407c2a639f89c89f5a09\nparent df06041eb2a9d593b7242763f2abd9b8460fe86b\nauthor Mason Daugherty <mason@langchain.dev> 1751566833 -0400\ncommitter GitHub <noreply@github.com> 1751566833 -0400\n\nlangchain[patch]: Add bandit rules (#31818)\n\nIntegrate Bandit for security analysis, suppress warnings for specific issues, and address potential vulnerabilities such as hardcoded passwords and SQL injection risks. Adjust documentation and formatting for clarity.',
#     'verified_at': '2025-07-03T18:20:34Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/6a5073b227feff67eae7ebf51cdc3bdc8d09c4b3/comments',
#   'author': {'login': 'mdrxy',
#    'id': 61371264,
#    'node_id': 'MDQ6VXNlcjYxMzcxMjY0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61371264?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mdrxy',
#    'html_url': 'https://github.com/mdrxy',
#    'followers_url': 'https://api.github.com/users/mdrxy/followers',
#    'following_url': 'https://api.github.com/users/mdrxy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mdrxy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mdrxy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mdrxy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mdrxy/orgs',
#    'repos_url': 'https://api.github.com/users/mdrxy/repos',
#    'events_url': 'https://api.github.com/users/mdrxy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mdrxy/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'df06041eb2a9d593b7242763f2abd9b8460fe86b',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/df06041eb2a9d593b7242763f2abd9b8460fe86b',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/df06041eb2a9d593b7242763f2abd9b8460fe86b'}]},
#  {'sha': 'df06041eb2a9d593b7242763f2abd9b8460fe86b',
#   'node_id': 'C_kwDOIPDwltoAKGRmMDYwNDFlYjJhOWQ1OTNiNzI0Mjc2M2YyYWJkOWI4NDYwZmU4NmI',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2025-07-03T18:12:10Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-03T18:12:10Z'},
#    'message': 'docs: Anthropic search_result nits (#31855)',
#    'tree': {'sha': 'da88aedbbeee6e96a0546595e88257124f0b61f5',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/da88aedbbeee6e96a0546595e88257124f0b61f5'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/df06041eb2a9d593b7242763f2abd9b8460fe86b',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nf5hBhihiZ4O+9SNZur8n\n=LcFD\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree da88aedbbeee6e96a0546595e88257124f0b61f5\nparent ade642b7c5bc3675bd864d67fbad16fc3cc8a585\nauthor ccurme <chester.curme@gmail.com> 1751566330 -0400\ncommitter GitHub <noreply@github.com> 1751566330 -0400\n\ndocs: Anthropic search_result nits (#31855)\n\n',
#     'verified_at': '2025-07-03T18:12:11Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/df06041eb2a9d593b7242763f2abd9b8460fe86b',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/df06041eb2a9d593b7242763f2abd9b8460fe86b',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/df06041eb2a9d593b7242763f2abd9b8460fe86b/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'ade642b7c5bc3675bd864d67fbad16fc3cc8a585',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ade642b7c5bc3675bd864d67fbad16fc3cc8a585',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/ade642b7c5bc3675bd864d67fbad16fc3cc8a585'}]},
#  {'sha': 'ade642b7c5bc3675bd864d67fbad16fc3cc8a585',
#   'node_id': 'C_kwDOIPDwltoAKGFkZTY0MmI3YzViYzM2NzViZDg2NGQ2N2ZiYWQxNmZjM2NjOGE1ODU',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2025-07-03T17:55:29Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-03T17:55:29Z'},
#    'message': 'Revert "infra: temporarily skip tests" (#31854)\n\nReverts langchain-ai/langchain#31853',
#    'tree': {'sha': '29aae17e78ef78e3528e1299ea48989ca239221a',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/29aae17e78ef78e3528e1299ea48989ca239221a'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/ade642b7c5bc3675bd864d67fbad16fc3cc8a585',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nPHHrVodej9yIJ0OLLXCP\n=GfAv\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 29aae17e78ef78e3528e1299ea48989ca239221a\nparent c9f45dc323bdc59d64a8acd1d264840bd2d3d23c\nauthor ccurme <chester.curme@gmail.com> 1751565329 -0400\ncommitter GitHub <noreply@github.com> 1751565329 -0400\n\nRevert "infra: temporarily skip tests" (#31854)\n\nReverts langchain-ai/langchain#31853',
#     'verified_at': '2025-07-03T17:55:29Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ade642b7c5bc3675bd864d67fbad16fc3cc8a585',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/ade642b7c5bc3675bd864d67fbad16fc3cc8a585',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ade642b7c5bc3675bd864d67fbad16fc3cc8a585/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'c9f45dc323bdc59d64a8acd1d264840bd2d3d23c',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c9f45dc323bdc59d64a8acd1d264840bd2d3d23c',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/c9f45dc323bdc59d64a8acd1d264840bd2d3d23c'}]},
#  {'sha': 'c9f45dc323bdc59d64a8acd1d264840bd2d3d23c',
#   'node_id': 'C_kwDOIPDwltoAKGM5ZjQ1ZGMzMjNiZGM1OWQ2NGE4YWNkMWQyNjQ4NDBiZDJkM2QyM2M',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2025-07-03T17:39:14Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-03T17:39:14Z'},
#    'message': 'infra: temporarily skip tests (#31853)\n\nTests failed twice with different timeout errors.',
#    'tree': {'sha': '99f69019e513681a8ffd4aed0b1fb4a8ba8eee95',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/99f69019e513681a8ffd4aed0b1fb4a8ba8eee95'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/c9f45dc323bdc59d64a8acd1d264840bd2d3d23c',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n3/rE7tx8Kn0v5ZqgnIy+\n=MOGa\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 99f69019e513681a8ffd4aed0b1fb4a8ba8eee95\nparent f88fff0b8a3a6e08531b6dfb2dde229c1f44d0c0\nauthor ccurme <chester.curme@gmail.com> 1751564354 -0400\ncommitter GitHub <noreply@github.com> 1751564354 -0400\n\ninfra: temporarily skip tests (#31853)\n\nTests failed twice with different timeout errors.',
#     'verified_at': '2025-07-03T17:39:14Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c9f45dc323bdc59d64a8acd1d264840bd2d3d23c',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/c9f45dc323bdc59d64a8acd1d264840bd2d3d23c',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c9f45dc323bdc59d64a8acd1d264840bd2d3d23c/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'f88fff0b8a3a6e08531b6dfb2dde229c1f44d0c0',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f88fff0b8a3a6e08531b6dfb2dde229c1f44d0c0',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/f88fff0b8a3a6e08531b6dfb2dde229c1f44d0c0'}]},
#  {'sha': 'f88fff0b8a3a6e08531b6dfb2dde229c1f44d0c0',
#   'node_id': 'C_kwDOIPDwltoAKGY4OGZmZjBiOGEzYTZlMDg1MzFiNmRmYjJkZGUyMjljMWY0NGQwYzA',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2025-07-03T17:18:43Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-03T17:18:43Z'},
#    'message': 'anthropic: release 0.3.17 (#31852)',
#    'tree': {'sha': '29aae17e78ef78e3528e1299ea48989ca239221a',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/29aae17e78ef78e3528e1299ea48989ca239221a'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/f88fff0b8a3a6e08531b6dfb2dde229c1f44d0c0',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nswLjkow+oqOvLHZczWqj\n=MSEK\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 29aae17e78ef78e3528e1299ea48989ca239221a\nparent 7cb9388c335fc3d2720fa22c9f155e9669f65b1e\nauthor ccurme <chester.curme@gmail.com> 1751563123 -0400\ncommitter GitHub <noreply@github.com> 1751563123 -0400\n\nanthropic: release 0.3.17 (#31852)\n\n',
#     'verified_at': '2025-07-03T17:18:43Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f88fff0b8a3a6e08531b6dfb2dde229c1f44d0c0',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/f88fff0b8a3a6e08531b6dfb2dde229c1f44d0c0',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f88fff0b8a3a6e08531b6dfb2dde229c1f44d0c0/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '7cb9388c335fc3d2720fa22c9f155e9669f65b1e',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/7cb9388c335fc3d2720fa22c9f155e9669f65b1e',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/7cb9388c335fc3d2720fa22c9f155e9669f65b1e'}]},
#  {'sha': '7cb9388c335fc3d2720fa22c9f155e9669f65b1e',
#   'node_id': 'C_kwDOIPDwltoAKDdjYjkzODhjMzM1ZmMzZDI3MjBmYTIyYzlmMTU1ZTk2NjlmNjViMWU',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2025-07-03T17:14:26Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-03T17:14:26Z'},
#    'message': 'Revert "infra: drop anthropic from core test matrix" (#31851)\n\nReverts langchain-ai/langchain#31850',
#    'tree': {'sha': '49dc5d8f5dc16ef1196f73838e47fb39ffe4c6fc',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/49dc5d8f5dc16ef1196f73838e47fb39ffe4c6fc'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/7cb9388c335fc3d2720fa22c9f155e9669f65b1e',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\ne8sMWcaEuDMlOqaIvkOF\n=Hxh6\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 49dc5d8f5dc16ef1196f73838e47fb39ffe4c6fc\nparent 21664985c7b388f62b46642839fda95db58d4bdf\nauthor ccurme <chester.curme@gmail.com> 1751562866 -0400\ncommitter GitHub <noreply@github.com> 1751562866 +0000\n\nRevert "infra: drop anthropic from core test matrix" (#31851)\n\nReverts langchain-ai/langchain#31850',
#     'verified_at': '2025-07-03T17:14:27Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/7cb9388c335fc3d2720fa22c9f155e9669f65b1e',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/7cb9388c335fc3d2720fa22c9f155e9669f65b1e',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/7cb9388c335fc3d2720fa22c9f155e9669f65b1e/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '21664985c7b388f62b46642839fda95db58d4bdf',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/21664985c7b388f62b46642839fda95db58d4bdf',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/21664985c7b388f62b46642839fda95db58d4bdf'}]},
#  {'sha': '21664985c7b388f62b46642839fda95db58d4bdf',
#   'node_id': 'C_kwDOIPDwltoAKDIxNjY0OTg1YzdiMzg4ZjYyYjQ2NjQyODM5ZmRhOTVkYjU4ZDRiZGY',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2025-07-03T16:52:25Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-03T16:52:25Z'},
#    'message': 'infra: drop anthropic from core test matrix (#31850)\n\nOverloaded errors blocking release. Will revert after.',
#    'tree': {'sha': 'bf6bf12592aea42603fb0e1702e96f0f73989a93',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/bf6bf12592aea42603fb0e1702e96f0f73989a93'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/21664985c7b388f62b46642839fda95db58d4bdf',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\na0vONflCst/bPosDt8k2\n=/67I\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree bf6bf12592aea42603fb0e1702e96f0f73989a93\nparent b140d166961b46e374e0b8a0547f591e9f31fe7a\nauthor ccurme <chester.curme@gmail.com> 1751561545 -0400\ncommitter GitHub <noreply@github.com> 1751561545 -0400\n\ninfra: drop anthropic from core test matrix (#31850)\n\nOverloaded errors blocking release. Will revert after.',
#     'verified_at': '2025-07-03T16:52:26Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/21664985c7b388f62b46642839fda95db58d4bdf',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/21664985c7b388f62b46642839fda95db58d4bdf',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/21664985c7b388f62b46642839fda95db58d4bdf/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'b140d166961b46e374e0b8a0547f591e9f31fe7a',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b140d166961b46e374e0b8a0547f591e9f31fe7a',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/b140d166961b46e374e0b8a0547f591e9f31fe7a'}]},
#  {'sha': 'b140d166961b46e374e0b8a0547f591e9f31fe7a',
#   'node_id': 'C_kwDOIPDwltoAKGIxNDBkMTY2OTYxYjQ2ZTM3NGUwYjhhMDU0N2Y1OTFlOWYzMWZlN2E',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2025-07-03T16:51:11Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-03T16:51:11Z'},
#    'message': 'docs: update ChatAnthropic guide (#31849)',
#    'tree': {'sha': '49dc5d8f5dc16ef1196f73838e47fb39ffe4c6fc',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/49dc5d8f5dc16ef1196f73838e47fb39ffe4c6fc'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/b140d166961b46e374e0b8a0547f591e9f31fe7a',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nG0pTfQjXaBoBjr5Uzxjc\n=5C3N\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 49dc5d8f5dc16ef1196f73838e47fb39ffe4c6fc\nparent 2090f85789acbb7a1ab9ee0515112b363fa521cc\nauthor ccurme <chester.curme@gmail.com> 1751561471 -0400\ncommitter GitHub <noreply@github.com> 1751561471 -0400\n\ndocs: update ChatAnthropic guide (#31849)\n\n',
#     'verified_at': '2025-07-03T16:51:12Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b140d166961b46e374e0b8a0547f591e9f31fe7a',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/b140d166961b46e374e0b8a0547f591e9f31fe7a',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b140d166961b46e374e0b8a0547f591e9f31fe7a/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '2090f85789acbb7a1ab9ee0515112b363fa521cc',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/2090f85789acbb7a1ab9ee0515112b363fa521cc',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/2090f85789acbb7a1ab9ee0515112b363fa521cc'}]},
#  {'sha': '2090f85789acbb7a1ab9ee0515112b363fa521cc',
#   'node_id': 'C_kwDOIPDwltoAKDIwOTBmODU3ODlhY2JiN2ExYWI5ZWUwNTE1MTEyYjM2M2ZhNTIxY2M',
#   'commit': {'author': {'name': 'ccurme',
#     'email': 'chester.curme@gmail.com',
#     'date': '2025-07-03T16:36:25Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-03T16:36:25Z'},
#    'message': 'core: release 0.3.68 (#31848)\n\nAlso add `search_result` to recognized tool message block types.',
#    'tree': {'sha': '2c60710f6df794f53df65aaf52580e15404cff90',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/2c60710f6df794f53df65aaf52580e15404cff90'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/2090f85789acbb7a1ab9ee0515112b363fa521cc',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nchvkXJBZVuZzvQ0ReGXg\n=SxcA\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 2c60710f6df794f53df65aaf52580e15404cff90\nparent 572020c4d860a9facc491ad0d9f034cd3bf02226\nauthor ccurme <chester.curme@gmail.com> 1751560585 -0400\ncommitter GitHub <noreply@github.com> 1751560585 -0400\n\ncore: release 0.3.68 (#31848)\n\nAlso add `search_result` to recognized tool message block types.',
#     'verified_at': '2025-07-03T16:36:26Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/2090f85789acbb7a1ab9ee0515112b363fa521cc',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/2090f85789acbb7a1ab9ee0515112b363fa521cc',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/2090f85789acbb7a1ab9ee0515112b363fa521cc/comments',
#   'author': {'login': 'ccurme',
#    'id': 26529506,
#    'node_id': 'MDQ6VXNlcjI2NTI5NTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26529506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ccurme',
#    'html_url': 'https://github.com/ccurme',
#    'followers_url': 'https://api.github.com/users/ccurme/followers',
#    'following_url': 'https://api.github.com/users/ccurme/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ccurme/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ccurme/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ccurme/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ccurme/orgs',
#    'repos_url': 'https://api.github.com/users/ccurme/repos',
#    'events_url': 'https://api.github.com/users/ccurme/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ccurme/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '572020c4d860a9facc491ad0d9f034cd3bf02226',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/572020c4d860a9facc491ad0d9f034cd3bf02226',
# ...
#    'repos_url': 'https://api.github.com/users/mdrxy/repos',
#    'events_url': 'https://api.github.com/users/mdrxy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mdrxy/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'b03e3262316923ec10505b4b61878c118ec66b5f',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b03e3262316923ec10505b4b61878c118ec66b5f',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/b03e3262316923ec10505b4b61878c118ec66b5f'}]},
#  {'sha': 'b03e3262316923ec10505b4b61878c118ec66b5f',
#   'node_id': 'C_kwDOIPDwltoAKGIwM2UzMjYyMzE2OTIzZWMxMDUwNWI0YjYxODc4YzExOGVjNjZiNWY',
#   'commit': {'author': {'name': 'Mason Daugherty',
#     'email': 'mason@langchain.dev',
#     'date': '2025-07-01T18:32:02Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-01T18:32:02Z'},
#    'message': 'langchain-prompty[patch]: Add ruff bandit rules to linter (#31814)\n\n- Add ruff bandit rules\n- Address some s101 assertion warnings\n- Address s506 by using `yaml.safe_load()`',
#    'tree': {'sha': 'c57aca9b8b4ffc5610b24d987675dba084a4e79d',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/c57aca9b8b4ffc5610b24d987675dba084a4e79d'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/b03e3262316923ec10505b4b61878c118ec66b5f',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nhh3LZmqKNBpXOC9huBra\n=8Hil\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree c57aca9b8b4ffc5610b24d987675dba084a4e79d\nparent 3190c4132fa00c0a31e85b524e71d69d64f16a94\nauthor Mason Daugherty <mason@langchain.dev> 1751394722 -0400\ncommitter GitHub <noreply@github.com> 1751394722 +0000\n\nlangchain-prompty[patch]: Add ruff bandit rules to linter (#31814)\n\n- Add ruff bandit rules\n- Address some s101 assertion warnings\n- Address s506 by using `yaml.safe_load()`',
#     'verified_at': '2025-07-01T18:32:02Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b03e3262316923ec10505b4b61878c118ec66b5f',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/b03e3262316923ec10505b4b61878c118ec66b5f',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/b03e3262316923ec10505b4b61878c118ec66b5f/comments',
#   'author': {'login': 'mdrxy',
#    'id': 61371264,
#    'node_id': 'MDQ6VXNlcjYxMzcxMjY0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61371264?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mdrxy',
#    'html_url': 'https://github.com/mdrxy',
#    'followers_url': 'https://api.github.com/users/mdrxy/followers',
#    'following_url': 'https://api.github.com/users/mdrxy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mdrxy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mdrxy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mdrxy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mdrxy/orgs',
#    'repos_url': 'https://api.github.com/users/mdrxy/repos',
#    'events_url': 'https://api.github.com/users/mdrxy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mdrxy/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': '3190c4132fa00c0a31e85b524e71d69d64f16a94',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3190c4132fa00c0a31e85b524e71d69d64f16a94',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/3190c4132fa00c0a31e85b524e71d69d64f16a94'}]},
#  {'sha': '3190c4132fa00c0a31e85b524e71d69d64f16a94',
#   'node_id': 'C_kwDOIPDwltoAKDMxOTBjNDEzMmZhMDBjMGEzMWU4NWI1MjRlNzFkNjlkNjRmMTZhOTQ',
#   'commit': {'author': {'name': 'Mason Daugherty',
#     'email': 'mason@langchain.dev',
#     'date': '2025-07-01T18:17:28Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-01T18:17:28Z'},
#    'message': 'langchain-perplexity[patch]: Add ruff bandit rules to linter (#31812)\n\n- Add ruff bandit rules',
#    'tree': {'sha': '779c7d3f889feae7d7ecf4ec74a73d8764a51d0a',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/779c7d3f889feae7d7ecf4ec74a73d8764a51d0a'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/3190c4132fa00c0a31e85b524e71d69d64f16a94',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nT4B8E1m9N/9trOARm4Sp\n=wiCt\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 779c7d3f889feae7d7ecf4ec74a73d8764a51d0a\nparent f30fe07620ce0ba68ca6eeaaa6fb63e41436b947\nauthor Mason Daugherty <mason@langchain.dev> 1751393848 -0400\ncommitter GitHub <noreply@github.com> 1751393848 +0000\n\nlangchain-perplexity[patch]: Add ruff bandit rules to linter (#31812)\n\n- Add ruff bandit rules',
#     'verified_at': '2025-07-01T18:17:29Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3190c4132fa00c0a31e85b524e71d69d64f16a94',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/3190c4132fa00c0a31e85b524e71d69d64f16a94',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3190c4132fa00c0a31e85b524e71d69d64f16a94/comments',
#   'author': {'login': 'mdrxy',
#    'id': 61371264,
#    'node_id': 'MDQ6VXNlcjYxMzcxMjY0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61371264?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mdrxy',
#    'html_url': 'https://github.com/mdrxy',
#    'followers_url': 'https://api.github.com/users/mdrxy/followers',
#    'following_url': 'https://api.github.com/users/mdrxy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mdrxy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mdrxy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mdrxy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mdrxy/orgs',
#    'repos_url': 'https://api.github.com/users/mdrxy/repos',
#    'events_url': 'https://api.github.com/users/mdrxy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mdrxy/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'f30fe07620ce0ba68ca6eeaaa6fb63e41436b947',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f30fe07620ce0ba68ca6eeaaa6fb63e41436b947',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/f30fe07620ce0ba68ca6eeaaa6fb63e41436b947'}]},
#  {'sha': 'f30fe07620ce0ba68ca6eeaaa6fb63e41436b947',
#   'node_id': 'C_kwDOIPDwltoAKGYzMGZlMDc2MjBjZTBiYTY4Y2E2ZWVhYWE2ZmI2M2U0MTQzNmI5NDc',
#   'commit': {'author': {'name': 'Mason Daugherty',
#     'email': 'mason@langchain.dev',
#     'date': '2025-07-01T18:16:38Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2025-07-01T18:16:38Z'},
#    'message': 'update pyproject.toml flake8 comment (#31810)',
#    'tree': {'sha': '35e0d912e24d3f0884261944f3ac3c48a1b04dd3',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/35e0d912e24d3f0884261944f3ac3c48a1b04dd3'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/f30fe07620ce0ba68ca6eeaaa6fb63e41436b947',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n6JX3rL3NW6XmuKPvfZ+a\n=GJtn\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 35e0d912e24d3f0884261944f3ac3c48a1b04dd3\nparent d0dce5315ffe9b9e4c987d21131c725c69400546\nauthor Mason Daugherty <mason@langchain.dev> 1751393798 -0400\ncommitter GitHub <noreply@github.com> 1751393798 +0000\n\nupdate pyproject.toml flake8 comment (#31810)\n\n',
#     'verified_at': '2025-07-01T18:16:38Z'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f30fe07620ce0ba68ca6eeaaa6fb63e41436b947',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/f30fe07620ce0ba68ca6eeaaa6fb63e41436b947',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f30fe07620ce0ba68ca6eeaaa6fb63e41436b947/comments',
#   'author': {'login': 'mdrxy',
#    'id': 61371264,
#    'node_id': 'MDQ6VXNlcjYxMzcxMjY0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61371264?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mdrxy',
#    'html_url': 'https://github.com/mdrxy',
#    'followers_url': 'https://api.github.com/users/mdrxy/followers',
#    'following_url': 'https://api.github.com/users/mdrxy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mdrxy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mdrxy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mdrxy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mdrxy/orgs',
#    'repos_url': 'https://api.github.com/users/mdrxy/repos',
#    'events_url': 'https://api.github.com/users/mdrxy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mdrxy/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'parents': [{'sha': 'd0dce5315ffe9b9e4c987d21131c725c69400546',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/d0dce5315ffe9b9e4c987d21131c725c69400546',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/d0dce5315ffe9b9e4c987d21131c725c69400546'}]}]

# %% [markdown]
# ## 解析导出每日进展
#
# API 请求返回结构过于复杂，我们先解析 `title` 字段，即仅查看和总结 GitHub 项目 Issues list 和 PRs List 标题。如下所示：
#
# ![Issues](images/issues.png)
#
# https://github.com/langchain-ai/langchain/issues

# %%
github_client.export_daily_progress(repo)
# Out:
# Exported daily progress to langchain-ai_langchain_2025-07-05.md
# 'langchain-ai_langchain_2025-07-05.md'

# %%
import sys
print(os.getcwd())
print(os.path.dirname(os.path.abspath(sys.argv[0])))
# Out:
# D:\Python\PythonProject\GitHubSentinel\src\jupyter
# C:\ProgramData\anaconda3\envs\Python3_12\Lib\site-packages

# %% [markdown]
# ### 查看文档 发现问题并不简单😈😈
#
# #### Note: Every pull request is an issue
#
# > GitHub's REST API considers every pull request an issue, but not every issue is a pull request. For this reason, "Issues" endpoints may return both issues and pull requests in the response. You can identify pull requests by the pull_request key. Be aware that the id of a pull request returned from "Issues" endpoints will be an issue id. To find out the pull request id, use the "List pull requests" endpoint.

# %% [markdown]
# # 支持条件筛选的 GitHub 项目进展获取
#
# 实际开发场景中，项目进展通常不是刚好以天为周期时。因此，这便暴露出v0.2版本的 `GitHubClient` 在信息获取方面的局限性。
#
#
# 下面我们扩展 v0.2 版本的 `GitHubClient`，使其支持根据筛选条件获取 GitHub 项目的 Issues 和 Pull Requests。首要支持的筛选条便是**研发周期（时间段）**，**已合并的PR** 和 **已关闭的Issues**：
#
# ![langchain_week_progress](images/langchain_week_progress.jpg)
#
# 通过阅读 GitHub API 文档（https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues--code-samples ），我们便能了解最关键的2个字段是：
#
# - state(string): Indicates the state of the issues to return.
#     - Default: open
#     - Can be one of: open, closed, all
# - since(string): Only show results that were last updated after the given time. This is a timestamp in ISO 8601 format: YYYY-MM-DDTHH:MM:SSZ.
#
# 从功能完整性角度，我们还可以增加一个 `until` 条件，以支持研发周期的结束时间筛选。😈😈
#
#
# 下面以 Langchain 项目 (https://github.com/langchain-ai/langchain) 为例，展示如何使用扩展后的 GitHubClient
#
# ## [v0.3] GitHubClient Class

# %%
# src/logger.py
from loguru import logger
import sys

# Configure Loguru
logger.remove()  # Remove the default logger
logger.add(sys.stdout, level="DEBUG", format="{time} {level} {message}", colorize=True)
logger.add("logs/app.log", rotation="1 MB", level="DEBUG")

# Alias the logger for easier import
LOG = logger

# Make the logger available for import with the alias
__all__ = ["LOG"]


# src/github_client.py

import requests  # 导入requests库用于HTTP请求
from datetime import datetime, date, timedelta  # 导入日期处理模块
import os  # 导入os模块用于文件和目录操作
# from logger import LOG  # 导入日志模块（演示时直接导入）

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub API令牌
        self.headers = {'Authorization': f'token {self.token}'}  # 设置HTTP头部认证信息

    def fetch_updates(self, repo, since=None, until=None):
        # 获取指定仓库的更新，可以指定开始和结束日期
        updates = {
            'commits': self.fetch_commits(repo, since, until),  # 获取提交记录
            'issues': self.fetch_issues(repo, since, until),  # 获取问题
            'pull_requests': self.fetch_pull_requests(repo, since, until)  # 获取拉取请求
        }
        return updates

    def fetch_commits(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/commits'  # 构建获取提交的API URL
        params = {}
        if since:
            params['since'] = since  # 如果指定了开始日期，添加到参数中
        if until:
            params['until'] = until  # 如果指定了结束日期，添加到参数中

        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()  # 检查请求是否成功
        return response.json()  # 返回JSON格式的数据

    def fetch_issues(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/issues'  # 构建获取问题的API URL
        params = {
            'state': 'closed',  # 仅获取已关闭的问题
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def fetch_pull_requests(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/pulls'  # 构建获取拉取请求的API URL
        params = {
            'state': 'closed',  # 仅获取已合并的拉取请求
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def export_daily_progress(self, repo):
        today = datetime.now().date().isoformat()  # 获取今天的日期
        updates = self.fetch_updates(repo, since=today)  # 获取今天的更新数据
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建存储路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        file_path = os.path.join(repo_dir, f'{today}.md')  # 构建文件路径
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(f"# Daily Progress for {repo} ({today})\n\n")
            file.write("\n## Issues Closed Today\n")
            for issue in updates['issues']:  # 写入今天关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged Today\n")
            for pr in updates['pull_requests']:  # 写入今天合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported daily progress to {file_path}")  # 记录日志
        return file_path

    def export_progress_by_date_range(self, repo, days):
        today = date.today()  # 获取当前日期
        since = today - timedelta(days=days)  # 计算开始日期
        
        updates = self.fetch_updates(repo, since=since.isoformat(), until=today.isoformat())  # 获取指定日期范围内的更新
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建目录路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        # 更新文件名以包含日期范围
        date_str = f"{since}_to_{today}"
        file_path = os.path.join(repo_dir, f'{date_str}.md')  # 构建文件路径
        
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(f"# Progress for {repo} ({since} to {today})\n\n")
            file.write(f"\n## Issues Closed in the Last {days} Days\n")
            for issue in updates['issues']:  # 写入在指定日期内关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged in the Last {days} Days\n")
            for pr in updates['pull_requests']:  # 写入在指定日期内合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported time-range progress to {file_path}")  # 记录日志
        return file_path

# %%
# 实例化 v0.3 版本的 GitHub Client
github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### 获取过去1天 LangChain 进展（已关闭的Issues）

# %%
# 获取今天的日期，从午夜开始，ISO 8601格式
today = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取今天关闭的Issues
closed_issues_today = github_client.fetch_issues(repo='langchain-ai/langchain', since=today, until=today)

# 打印今天关闭的Issues标题
for issue in closed_issues_today:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")

# %%
# 获取过去3天的日期
three_days_ago = datetime.now() - timedelta(days=3)
three_days_ago = three_days_ago.replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取过去3天关闭的Issues
closed_issues_last_3_days = github_client.fetch_issues(repo='langchain-ai/langchain', since=three_days_ago, until=today)

# 打印过去3天关闭的Issues标题
for issue in closed_issues_last_3_days:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")
# Out:
# Issue #31855: docs: Anthropic search_result nits (关闭时间 2025-07-03T18:12:10Z)
# Issue #31854: Revert "infra: temporarily skip tests" (关闭时间 2025-07-03T17:55:29Z)
# Issue #31853: infra: temporarily skip tests (关闭时间 2025-07-03T17:39:14Z)
# Issue #31852: anthropic: release 0.3.17 (关闭时间 2025-07-03T17:18:43Z)
# Issue #31851: Revert "infra: drop anthropic from core test matrix" (关闭时间 2025-07-03T17:14:27Z)
# Issue #31850: infra: drop anthropic from core test matrix (关闭时间 2025-07-03T16:52:25Z)
# Issue #31849: docs: update ChatAnthropic guide (关闭时间 2025-07-03T16:51:11Z)
# Issue #31848: core: release 0.3.68 (关闭时间 2025-07-03T16:36:25Z)
# Issue #31847: docs: anthropic formatting cleanup (关闭时间 2025-07-03T14:50:23Z)
# Issue #31844: text-splitters: 0.3.9 (关闭时间 2025-07-03T14:02:35Z)
# Issue #31843: cli: Add ruff rule UP (pyupgrade) (关闭时间 2025-07-03T14:12:47Z)
# Issue #31842: standard-tests: Add ruff rule UP (pyupgrade) (关闭时间 2025-07-03T14:12:31Z)
# Issue #31841: text-splitters: Add ruff rule UP (pyupgrade) (关闭时间 2025-07-03T14:11:35Z)
# Issue #31840: Update sql_qa.ipynb (关闭时间 2025-07-03T15:09:16Z)
# Issue #31839: core: Use parametric tests in test_openai_tools (关闭时间 2025-07-03T12:43:46Z)
# Issue #31838: Making Repo black and Isort for better code formating (关闭时间 2025-07-03T12:47:55Z)
# Issue #31835: docs: Integration with GreenNode Serverless AI Studio (关闭时间 2025-07-03T05:59:21Z)
# Issue #31834: text-splitters: bump spacy version to 3.8.7 (关闭时间 2025-07-03T14:13:25Z)
# Issue #31833: docs: Add PR info doc (关闭时间 2025-07-02T19:20:27Z)
# Issue #31831: update CODEOWNERS (关闭时间 2025-07-02T21:31:50Z)
# Issue #31830: ci: set explicit workflow permissions (关闭时间 2025-07-03T14:02:18Z)
# Issue #31828: o3 price not updated (关闭时间 2025-07-02T15:29:19Z)
# Issue #31823: core: Add MinifiedPydanticOutputParser to Optimize Token Usage in LLM Outputs 🚀 (关闭时间 2025-07-02T14:18:51Z)
# Issue #31820: docs: Update agents.ipynb (关闭时间 2025-07-02T14:42:28Z)
# Issue #31819: text-splitters[patch]: Remove xslt_path and harden XML parsers in HTMLSectionSplitter (关闭时间 2025-07-02T19:24:08Z)
# Issue #31818: langchain[patch]: Add bandit rules (关闭时间 2025-07-03T18:20:33Z)
# Issue #31817: This PR introduces a new loader class, `UniversalDocumentLoader`, which follows the **Strategy Pattern** to dynamically delegate document loading to the appropriate loader class based on the file type. It aims to simplify file ingestion in LangChain applications that deal with a variety of document formats (e.g., PDF, RTF, TXT). (关闭时间 2025-07-02T14:41:48Z)
# Issue #31813: core[path]: Use context manager for FileCallbackHandler (关闭时间 2025-07-02T17:31:58Z)
# Issue #31801: groq: Add service tier option to ChatGroq (关闭时间 2025-07-03T14:11:18Z)
# Issue #31784: ollama: add `validate_model_on_init`, catch more errors (关闭时间 2025-07-03T15:07:11Z)

# %% [markdown]
# ## 优化导出文件管理
#
# 考虑到 GitHubSentinel 项目长期运行将会生成一大批项目进展文件，因此将所有进展文件统一存储在`daily_progress` 目录下，并按照 `{owners}_{repo}/{since_day}_{until_day}.md` 方式命名。
#
# 如下所示：
#
# ```shell
# daily_progress
# ├── langchain-ai_langchain
# │   ├── 2024-08-04.md
# │   ├── 2024-08-04_report.md
# │   ├── 2024-08-18.md
# │   └── 2024-08-18_report.md
# ├── llm_logs.log
# ├── ollama_ollama
# │   ├── 2024-07-30_to_2024-08-04.md
# │   ├── 2024-07-30_to_2024-08-04_report.md
# │   ├── 2024-08-02_to_2024-08-04.md
# │   ├── 2024-08-02_to_2024-08-04_report.md
# │   ├── 2024-08-04.md
# │   └── 2024-08-04_report.md
# ```

# %%
github_client.export_progress_by_date_range(repo='langchain-ai/langchain', days=3)
# Out:
# 2025-07-05T09:19:59.722902+0800 INFO Exported time-range progress to daily_progress\langchain-ai_langchain\2025-07-02_to_2025-07-05.md
# 'daily_progress\\langchain-ai_langchain\\2025-07-02_to_2025-07-05.md'

# %%
github_client.export_daily_progress(repo='langchain-ai/langchain')
# Out:
# 2025-07-05T09:20:17.701268+0800 INFO Exported daily progress to daily_progress\langchain-ai_langchain\2025-07-05.md
# 'daily_progress\\langchain-ai_langchain\\2025-07-05.md'

# %% [markdown]
# ### Homework: [可选] 尝试扩展 GitHubClient，使其支持 Since + Until 参数的特定时间段筛选
# ![image.png](attachment:12c41fc1-1001-4b5c-9905-131457956a2e.png)![image.png](attachment:532f2f6e-17e4-4d49-934e-d7301d9e8d9b.png)![image.png](attachment:d7c01738-e689-409e-b9aa-476cad3f8220.png)![image.png](attachment:bd00a348-af22-4a69-b64d-5f676f9ed7ee.png)

# %%
# src/github_client.py

import requests
import datetime
from typing import Optional, List, Dict, Any

class GitHubClient:
    def __init__(self, token: str):
        """
        初始化GitHub客户端。
        :param token: 你的GitHub Personal Access Token。
        """
        if not token:
            raise ValueError("GitHub token cannot be empty.")
        self.token = token
        self.headers = {
            'Authorization': f'token {self.token}',
            'Accept': 'application/vnd.github.v3+json' # 推荐明确指定API版本
        }
        self.api_base_url = 'https://api.github.com'

    def _format_date(self, dt: datetime.datetime) -> str:
        """将datetime对象格式化为GitHub API接受的ISO 8601字符串。"""
        return dt.isoformat()

    def fetch_commits(self, repo: str, since: Optional[datetime.datetime] = None, until: Optional[datetime.datetime] = None) -> List[Dict[str, Any]]:
        """
        获取指定仓库在特定时间段内的提交记录。
        :param repo: 仓库名，格式为 'owner/repo'。
        :param since: 开始时间。
        :param until: 结束时间。
        :return: 提交列表。
        """
        url = f'{self.api_base_url}/repos/{repo}/commits'
        params = {}
        if since:
            params['since'] = self._format_date(since)
        if until:
            params['until'] = self._format_date(until)

        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def _search_issues_and_prs(self, repo: str, since: datetime.datetime, until: datetime.datetime, item_type: str = "issue", state: str = "closed") -> List[Dict[str, Any]]:
        """
        使用GitHub Search API精确查找在时间段内关闭或合并的Issues/PRs。
        这是比直接列出更高效的方法。
        """
        url = f'{self.api_base_url}/search/issues'
        date_format = "%Y-%m-%d"

        # 构建搜索查询语句
        # 示例: repo:langchain-ai/langchain is:pr is:merged merged:2023-01-01..2023-01-31
        query_parts = [
            f"repo:{repo}",
            f"is:{item_type}"
        ]
        if item_type == "pr" and state == "merged":
            query_parts.append("is:merged")
            query_parts.append(f"merged:{since.strftime(date_format)}..{until.strftime(date_format)}")
        elif item_type == "issue" and state == "closed":
            query_parts.append("is:closed")
            query_parts.append(f"closed:{since.strftime(date_format)}..{until.strftime(date_format)}")

        query = " ".join(query_parts)
        params = {'q': query, 'per_page': 100} # 每页最多100条

        print(f"Searching with query: {query}") # 调试信息

        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        # Search API的结果在 'items' 键下
        return response.json().get('items', [])

    def fetch_closed_issues_in_range(self, repo: str, since: datetime.datetime, until: datetime.datetime) -> List[Dict[str, Any]]:
        """获取在指定时间段内关闭的Issues。"""
        return self._search_issues_and_prs(repo, since, until, item_type="issue", state="closed")

    def fetch_merged_pull_requests_in_range(self, repo: str, since: datetime.datetime, until: datetime.datetime) -> List[Dict[str, Any]]:
        """获取在指定时间段内合并的Pull Requests。"""
        return self._search_issues_and_prs(repo, since, until, item_type="pr", state="merged")

    def export_progress_by_date_range(self, repo: str, since: datetime.datetime, until: datetime.datetime):
        """
        导出指定仓库在特定时间段内的进度报告（关闭的Issues和合并的PRs）。
        """
        date_format = "%Y-%m-%d"
        filename = f"{repo.replace('/', '_')}_{since.strftime(date_format)}_to_{until.strftime(date_format)}.md"

        # 获取数据
        closed_issues = self.fetch_closed_issues_in_range(repo, since, until)
        merged_prs = self.fetch_merged_pull_requests_in_range(repo, since, until)

        # 使用 utf-8 编码写入文件，避免 UnicodeEncodeError
        with open(filename, 'w', encoding='utf-8') as f:
            f.write(f"# {repo} Progress Report\n")
            f.write(f"**Period:** {since.strftime(date_format)} to {until.strftime(date_format)}\n\n")

            f.write("## ✅ Issues Closed\n")
            if closed_issues:
                for issue in closed_issues:
                    f.write(f"- {issue['title']} #{issue['number']}\n")
            else:
                f.write("- None\n")

            f.write("\n## 🚀 Pull Requests Merged\n")
            if merged_prs:
                for pr in merged_prs:
                    f.write(f"- {pr['title']} #{pr['number']}\n")
            else:
                f.write("- None\n")

        print(f"Successfully exported progress report to {filename}")
        return filename

# %%
import os
from dotenv import load_dotenv

# 从 .env 文件加载环境变量
load_dotenv()
# 请确保你的 .env 文件中有 GITHUB_TOKEN="ghp_..."
github_token = os.getenv("GITHUB_TOKEN")

if not github_token:
    print("Error: GITHUB_TOKEN not found in environment variables or .env file.")
else:
    # 1. 初始化客户端
    client = GitHubClient(token=github_token)

    # 2. 定义要查询的仓库和时间范围
    target_repo = 'langchain-ai/langchain'
    end_date = datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(days=7)
    start_date = end_date - datetime.timedelta(days=7)

    # 3. 调用新的导出方法
    try:
        client.export_progress_by_date_range(
            repo=target_repo,
            since=start_date,
            until=end_date
        )
    except requests.exceptions.HTTPError as e:
        print(f"An HTTP error occurred: {e}")
        print(f"Response body: {e.response.text}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
# Out:
# Searching with query: repo:langchain-ai/langchain is:issue is:closed closed:2025-06-21..2025-06-28
# Searching with query: repo:langchain-ai/langchain is:pr is:merged merged:2025-06-21..2025-06-28
# Successfully exported progress report to langchain-ai_langchain_2025-06-21_to_2025-06-28.md
